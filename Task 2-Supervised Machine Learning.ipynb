# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# # Importing and processing the data

# %% [markdown]
# url = "https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv"
# data = pd.read_csv(url)
# print("Success")

# %%
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
data.tail()
# Out:
#     Hours  Scores
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
data.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %% [markdown]
# # Plotting the data

# %%
data.plot(x='Hours', y='Scores', style='o')
plt.title('Hours vs Scores')  
plt.xlabel('Hours')  
plt.ylabel('Percentage Score')  
plt.show()

# %% [markdown]
# # Training and Testing the data

# %%
x = data.iloc[:, :-1].values
y = data.iloc[:, 1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
r = LinearRegression()
r.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train,y_train)
plt.title("Train data")
plt.xlabel('Hours')  
plt.ylabel('Percentage Score')
plt.plot(x_train,r.coef_*x_train+r.intercept_,color="red")

# %% [markdown]
# # Predicting the data

# %%
pred=r.predict(x_test)

# %%
data1=pd.DataFrame({"Actual":y_test,"predicted":pred})
data1
# Out:
#    Actual  predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, pred))
# Out:
# Mean Absolute Error: 4.183859899002982

# %%
req=r.predict([[9.25]])
print("For 9.25 hours, the precited score is {}".format(req[0]))
# Out:
# For 9.25 hours, the precited score is 93.69173248737539
